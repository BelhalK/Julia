# %%
N = 5
fact = 1
for i=1:N
    fact = fact*i
end

# %%
print(fact)
# Out:
# 120

# %%
using Pkg

# %%
using ScikitLearn

# %%
using DataFrames

# %%
data = readtable("data/data.csv")
# Out:
# ┌ Warning: readtable is deprecated, use CSV.read from the CSV package instead
# │   caller = top-level scope at In[7]:1
# └ @ Core In[7]:1
# 8014×13 DataFrame. Omitted printing of 12 columns
# │ Row  │ smiles                                                          │
# │      │ Union{Missing, String}                                          │
# ├──────┼─────────────────────────────────────────────────────────────────┤
# │ 1    │ CCOc1ccc2nc(S(N)(=O)=O)sc2c1                                    │
# │ 2    │ CCN1C(=O)NC(c2ccccc2)C1=O                                       │
# │ 3    │ CC[C@]1(O)CC[C@H]2[C@@H]3CCC4=CCCC[C@@H]4[C@H]3CC[C@@]21C       │
# │ 4    │ CCCN(CC)C(CC)C(=O)Nc1c(C)cccc1C                                 │
# │ 5    │ CC(O)(P(=O)(O)O)P(=O)(O)O                                       │
# │ 6    │ CC(C)(C)OOC(C)(C)CCC(C)(C)OOC(C)(C)C                            │
# │ 7    │ O=S(=O)(Cl)c1ccccc1                                             │
# ...

# %%
first(data,6)
# Out:
# 6×13 DataFrame. Omitted printing of 11 columns
# │ Row │ smiles                                                    │ target1 │
# │     │ Union{Missing, String}                                    │ Int64⍰  │
# ├─────┼───────────────────────────────────────────────────────────┼─────────┤
# │ 1   │ CCOc1ccc2nc(S(N)(=O)=O)sc2c1                              │ 0       │
# │ 2   │ CCN1C(=O)NC(c2ccccc2)C1=O                                 │ 0       │
# │ 3   │ CC[C@]1(O)CC[C@H]2[C@@H]3CCC4=CCCC[C@@H]4[C@H]3CC[C@@]21C │ missing │
# │ 4   │ CCCN(CC)C(CC)C(=O)Nc1c(C)cccc1C                           │ 0       │
# │ 5   │ CC(O)(P(=O)(O)O)P(=O)(O)O                                 │ 0       │
# │ 6   │ CC(C)(C)OOC(C)(C)CCC(C)(C)OOC(C)(C)C                      │ 0       │

# %%
describe(data)
# Out:
# 13×8 DataFrame. Omitted printing of 2 columns
# │ Row │ variable │ mean      │ min       │ median │ max        │ nunique │
# │     │ Symbol   │ Union…    │ Any       │ Union… │ Any        │ Union…  │
# ├─────┼──────────┼───────────┼───────────┼────────┼────────────┼─────────┤
# │ 1   │ smiles   │           │ BrC(Br)Br │        │ c1nc[nH]n1 │ 7831    │
# │ 2   │ target1  │ 0.0416723 │ 0         │ 0.0    │ 1          │         │
# │ 3   │ target2  │ 0.0344828 │ 0         │ 0.0    │ 1          │         │
# │ 4   │ target3  │ 0.117322  │ 0         │ 0.0    │ 1          │         │
# │ 5   │ target4  │ 0.0516835 │ 0         │ 0.0    │ 1          │         │
# │ 6   │ target5  │ 0.126346  │ 0         │ 0.0    │ 1          │         │
# │ 7   │ target6  │ 0.0500562 │ 0         │ 0.0    │ 1          │         │
# │ 8   │ target7  │ 0.0287103 │ 0         │ 0.0    │ 1          │         │
# │ 9   │ target8  │ 0.161921  │ 0         │ 0.0    │ 1          │         │
# ...

# %%
 using Plots, StatPlots
# Out:
# ┌ Info: Precompiling StatPlots [60ddc479-9b66-56df-82fc-76a74619b69c]
# └ @ Base loading.jl:1192

# %%
 Plots.histogram(data[1:2,:target3],bins=50,xlabel="target3",labels="Frequency")
